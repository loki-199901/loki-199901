# %% [markdown]
# <a href="https://colab.research.google.com/github/loki-199901/loki-199901/blob/main/DS_Lecture1_08_03_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First we want to read and clean data
# to read data we use pandas as pd in python

import pandas as pd
# ab data ma kya ha
# if its statics ha we use numpy as np

import numpy as np

#ab data ko read karna ha

#ab aik variable ko data assig kar dain ga

d = pd.read_csv('/content/sample_data/california_housing_train.csv')

#hum na data show karwana ha

d.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# ab hum na data ko check kara ha ka kuch missing to nhi ha

# first step is to find the data type of this dataset

d.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
#dtype object Is ka meaning ha ya data apas ma depedent ha on each other
# ab check kara ka kuch miss to nhi

d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
# means koi missing value nhi ha
# phir bhi confirm kar lain

d.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
# ab hum data ka frame nikal lata hain
# df is ka kiz or kon si value -ive hain ya +ive
d.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# ab datascience wala kam wo kia graphic draw karna ha
# jo last output ha us pa

import matplotlib.pyplot as plt

# jub hama nhi pata ka data kasa ha to us seaborn as sns kar dain ga
import seaborn as sns

sns.distplot(d['longitude'],bins=10)

plt.title('Python Class DS')
plt.show()
# Out:
# <ipython-input-16-b0197ec4f7cb>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['longitude'],bins=10)

# %%
# isis data ma sa ab ya pata karta hain k kitni unique value ha
d['total_rooms'].unique()
# Out:
# array([5612., 7650.,  720., ..., 3810., 3003., 2694.])

# %%
#kis colunmn ma kon si unique roo ha count karta
d['total_rooms'].value_counts()
# Out:
# total_rooms
# 1582.0     16
# 1527.0     15
# 1717.0     14
# 1703.0     14
# 1471.0     14
#            ..
# 5896.0      1
# 11275.0     1
# 10626.0     1
# 151.0       1
# 2694.0      1
# Name: count, Length: 5533, dtype: int64

# %%
#total price prediction kitni ha
d['median_house_value'].mean()
# Out:
# 207300.91235294117

# %%
d['median_house_value'].head()
# Out:
# 0    66900.0
# 1    80100.0
# 2    85700.0
# 3    73400.0
# 4    65500.0
# Name: median_house_value, dtype: float64

# %%
# isi price ka graph draw karna ha'

sns.distplot(d['median_house_value'],bins=20)
plt.show()
# Out:
# <ipython-input-23-8d2acce30f6b>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['median_house_value'],bins=20)
